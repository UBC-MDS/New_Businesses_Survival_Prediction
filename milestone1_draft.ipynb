# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Loading dataset

# %%
# csv_url = 'https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/business-licences/exports/csv?lang=en&timezone=America%2FLos_Angeles&use_labels=true&delimiter=%3B'
# business = pd.read_csv(csv_url, delimiter = ';')

# It takes a while to load data from the url, so... here's the shortcut!
# Just download the file above to your local machine, and put the file in the data folder
business = pd.read_csv('data/business-licences.csv', delimiter = ';')
# Out:
# /var/folders/x5/4d64q7td2l59kf73lvykgkq40000gn/T/ipykernel_44848/3829125622.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   business = pd.read_csv('business-licences.csv', delimiter = ';')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Cleaning data
# - Drop rows where `ExpiredDate` and `IssuedDate` are NA.
# - Transform `ExpiredDate` and `IssuedDate` to date.
# - Calculate the survival interval of each company, which is the difference between the maximum of ExpiredDate and the minimum of IssuedDate.
# - Keep only the newest issued record of each company.
# - Filter to keep those records where the latest `ExpiredDate` is before or equal to year 2022 because for those licenses issued in year 2023, the dafault `ExpiredDate` are `2023-12-31` and we cannot know whether it would survive until then.

# %%
# Drop rows where ExpiredDate and IssuedDate are NA
business = business.dropna(subset = ["ExpiredDate", "IssuedDate"])

# Transform ExpiredDate and IssuedDate to date
business[["ExpiredDate", "IssuedDate"]] = business[["ExpiredDate", "IssuedDate"]].apply(pd.to_datetime, utc=True)
business['ExpiredDate'] = business['ExpiredDate'].dt.date
business['IssuedDate'] = business['IssuedDate'].dt.date

# Calculate the survival interval of each company
business['survival_days'] = (business.groupby('BusinessName')['ExpiredDate'].transform('max')-
                            business.groupby('BusinessName')['IssuedDate'].transform('min'))

# Keep only the newest issued record of each company
business.sort_values(by='ExpiredDate', ascending=True)
business = business.drop_duplicates(subset='BusinessName', keep='last')

# Filter to keep those records where the latest `ExpiredDate` is before or equal to year 2022.
business = business[business['ExpiredDate'] <= dt.date(2022, 12, 31)]

# %%
# business[(business["IssuedDate"] >= dt.date(2023, 1, 1)) & (business["Status"] == 'Issued')]
# business.iloc[381746, :]
# business[business['BusinessName'] == 'Lehail Construction Ltd']
# business.sort_values(by='ExpiredDate', ascending=True)

# %% [markdown]
# ### Response Variable for Classification: survival_status

# %%
survival_threshold = dt.timedelta(days=365)
business['survival_status'] = business['survival_days'] >= survival_threshold
business
# Out:
#         FOLDERYEAR  LicenceRSN LicenceNumber  LicenceRevisionNumber  \
# 21              13     1786109     13-166693                      0
# 26              13     1786136     13-166720                      0
# 27              13     1786138     13-166722                      0
# 29              13     1786144     13-166728                      0
# 36              13     1786165     13-166749                      0
# ...            ...         ...           ...                    ...
# 646924          21     3724155     21-141639                      0
# 646928          21     3724163     21-141647                      0
# 646935          21     3724233     21-141717                      0
# 646950          21     3724334     21-141818                      0
# 646957          21     3724406     21-141890                      0
#
#                                       BusinessName  \
# 21      David Andrew Goodfellow (David Goodfellow)
# 26       William David McKnight (William McKnight)
# 27                              (Thomas MacDonald)
# 29                                (Janet Morrison)
# 36       Laura Rose Martin Barreca (Laura Barreca)
# ...                                            ...
# 646924                    Six Oh Four Printing Ltd
# 646928          Saing Chun Derek Chan (Saing Chan)
# 646935         Ricardo W Thaller (Ricardo Thaller)
# 646950              Vital Plumbing And Heating Inc
# 646957                Altra Urban Construction Ltd
#
#                           BusinessTradeName    Status  IssuedDate ExpiredDate  \
# 21                  Bramblebutt Productions    Issued  2012-12-22  2013-12-31
# 26                                      NaN    Issued  2012-12-28  2013-12-31
# 27                      Mr. MacDonald Music    Issued  2013-01-30  2013-12-31
# 29              Janet Love Morrison Editing    Issued  2012-12-22  2013-12-31
# 36                                      NaN    Issued  2013-06-14  2013-12-31
# ...                                     ...       ...         ...         ...
# 646924                        Made in Print    Issued  2020-12-01  2021-12-31
# 646928  RSVP Wedding Invitations & Printing    Issued  2021-02-10  2021-12-31
# 646935                                  NaN    Issued  2021-04-07  2021-12-31
# 646950                                  NaN  Inactive  2021-02-08  2021-12-31
# 646957             Altra Urban Construction    Issued  2020-11-26  2021-12-31
#
#                     BusinessType  ... Country PostalCode            LocalArea  \
# 21        Entertainment Services  ...      CA        NaN       Mount Pleasant
# 26        Entertainment Services  ...      CA        NaN   Grandview-Woodland
# 27        Entertainment Services  ...      CA        NaN   Grandview-Woodland
# 29        Entertainment Services  ...      CA        NaN             West End
# 36        Entertainment Services  ...      CA        NaN       Mount Pleasant
# ...                          ...  ...     ...        ...                  ...
# 646924         Printing Services  ...      CA    V6B 1C2             Downtown
# 646928         Printing Services  ...      CA    V6A 1H9           Strathcona
# 646935  Plumber & Gas Contractor  ...      CA        NaN         South Cambie
# 646950  Plumber & Gas Contractor  ...      CA        NaN             West End
# 646957  Plumber & Gas Contractor  ...      CA        NaN  Victoria-Fraserview
#
#        NumberofEmployees FeePaid                ExtractDate  \
# 21                   1.0   129.0  2019-07-21T13:49:06-07:00
# 26                   0.0   129.0  2019-07-21T13:49:06-07:00
# 27                   0.0   169.0  2019-07-21T13:49:06-07:00
# 29                   1.0   129.0  2019-07-21T13:49:06-07:00
# 36                   0.0   151.0  2019-07-21T13:49:06-07:00
# ...                  ...     ...                        ...
# 646924               5.0   155.0  2023-11-01T02:38:57-07:00
# 646928               1.0   195.0  2023-11-01T02:38:57-07:00
# 646935               1.0   390.0  2023-11-01T02:38:57-07:00
# 646950               0.0   195.0  2023-11-01T02:38:57-07:00
# 646957               1.0   155.0  2023-11-01T02:38:57-07:00
#
#                                                      Geom  \
# 21                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 29                                                    NaN
# 36                                                    NaN
# ...                                                   ...
# 646924  {"coordinates": [-123.114538756358, 49.2766297...
# 646928  {"coordinates": [-123.08364749238, 49.28233634...
# 646935                                                NaN
# 646950                                                NaN
# 646957                                                NaN
#
#                                geo_point_2d       survival_days  \
# 21                                      NaN   374 days, 0:00:00
# 26                                      NaN   368 days, 0:00:00
# 27                                      NaN   335 days, 0:00:00
# 29                                      NaN   374 days, 0:00:00
# 36                                      NaN   200 days, 0:00:00
# ...                                     ...                 ...
# 646924  49.2766297368584, -123.114538756358  2348 days, 0:00:00
# 646928   49.2823363433113, -123.08364749238  3672 days, 0:00:00
# 646935                                  NaN  3220 days, 0:00:00
# 646950                                  NaN  1255 days, 0:00:00
# 646957                                  NaN  3683 days, 0:00:00
#
#        survival_status
# 21                True
# 26                True
# 27               False
# 29                True
# 36               False
# ...                ...
# 646924            True
# 646928            True
# 646935            True
# 646950            True
# 646957            True
#
# [50891 rows x 27 columns]

# %% [markdown]
# ## EDA & Visualization
